# %% [markdown]
# ## Week5: Day 1 - Introduction to Hypothesis Testing in Python

# %% [markdown]
# # Hypothesis Testing
#
# From lecture, we know that hypothesis testing is critical tool in determing what the value of a parameter could be
#
# We know that the basis of our testing has two attributes:
#
# ### Null Hypothesis: Ho
#
# ### Alternative Hypothesis: Ha
#
# The tests we have discussed in lecture are
#
# - One Population Proportion
# - Difference in Population Proportions
# - One Population Mean
# - Difference in Population Means
#
# In this tutorial, I will introduce some functions that are extremely useful when caluating at state and valu
#
# hypothesis test.
#
# Lets quickly review the following ways to calculate a test statistic for the tests listed above.
#
# The equations is:
#                            Best Estimate - Hypothesized Estimate
#                            __________________________________
#                            Standard Error of Estimate
#
# We will use the examples from our lectures and use python functions to streamline our tests.

# %%
import statsmodels.api as sn 
import numpy as np 
import pandas as pd

# %% [markdown]
# ## One Population Proportion

# %% [markdown]
# ### Research Question
#
# In previous years 52% of parents believed that electronics and social media was the cause of their teenager's lack of sleep. Do more parents today believe that their teenager's lack of sleep is caused due to electronics and social media?
#
# #### Population Parents with a teenager (age 13-18)
# #### Parameter of Interest p
# #### Null Hypothesis: p=0.52
# #### Alternative Hypthosis: p>0.52
#
# Out of 1018 Parents, 56% believe that their teenager's lack of sleep is caused due to electronics and social media.

# %%
#n is the number of parents
n = 1018
# null hypothesis
pnull=.52 
#Observed published porportion(percentage)
phat=.56
# Hypothesis test for one population porportion
sn.stats.proportions_ztest (phat * n, n, pnull)

#We can reject null value as we can see through our stats(pvalue(.0101) < alphavalue) that it is much more higher than that
# Out:
# (2.571067795759113, 0.010138547731721065)

# %% [markdown]
# ### Difference in Population Proportions
#
# #### Research Question
#
# Is there a significant difference between the population proportions of parents of black children and parents of Hispanic children who report that their child has had some swimming lessons?
#
# #### Populations: All parents of black children age 6-18 and all parents of Hispanic children age 6-18
# #### Parameter of Interest: p1-p2, where p1 = black and p2 = hispanic
# #### Null Hypothesis: p1-p2 = 0
# #### Alternative Hypthosis: p1-p2 is not = 0
#
# 247 Parents of Black Children 36.8% of parents report that their child has had some swimming lessons
#
# 308 Parents of Hispanic Children 38.9% of parents report that their child has had some swimming lessons

# %%
n1=247 
p1=.37

n2=308
p2=.39

population1=np.random.binomial(1, p1, n1) 
population2= np.random.binomial(1, p2, n2)

sn.stats.ttest_ind(population1, population2)
# Out:
# (-2.061472095415461, 0.039724847284100175, 553.0)

# %% [markdown]
# ### One Population Mean

# %% [markdown]
# ### Research Question
#
# Is the average cartwheel distance (in inches) for adults more than 80 inches?
#
# #### Population: All adults
# #### Parameter of Interest: µ. population mean cartwheel distance.
# #### Null Hypothesis:µ = 80
# #### Alternative Hypthosis:µ >80
#
# 25 Adults
#
# μ=82.46
#
# a=15.06

# %%
df = pd.read_csv("Cartwheeldata.csv")

df.head
# Out:
# <bound method NDFrame.head of     ID  Age Gender  GenderGroup Glasses  GlassesGroup  Height  Wingspan  \
# 0    1   56      F            1       Y             1   62.00      61.0
# 1    2   26      F            1       Y             1   62.00      60.0
# 2    3   33      F            1       Y             1   66.00      64.0
# 3    4   39      F            1       N             0   64.00      63.0
# 4    5   27      M            2       N             0   73.00      75.0
# 5    6   24      M            2       N             0   75.00      71.0
# 6    7   28      M            2       N             0   75.00      76.0
# 7    8   22      F            1       N             0   65.00      62.0
# 8    9   29      M            2       Y             1   74.00      73.0
# 9   10   33      F            1       Y             1   63.00      60.0
# 10  11   30      M            2       Y             1   69.50      66.0
# 11  12   28      F            1       Y             1   62.75      58.0
# ...

# %%
n = len(df)
mean = df['CWDistance'].mean() 
sd = df['CWDistance'].std()

(n, mean, sd)
# Out:
# (25, 82.48, 15.058552387264855)

# %%
sn.stats.ztest(df["CWDistance"], value=80, alternative='larger')
# Out:
# (0.8234523266982029, 0.20512540845395266)

# %% [markdown]
# ### Difference in Population Means

# %% [markdown]
# ##### Research Question
#
# Considering adults in the NHANES data, do males have a significantly higher mean Body Mass Index than females?
#
# ##### Population: Adults in the NHANES data
#
# ##### Parameter of Interest: μ1-μ2. Body Mass Index.
#
# ##### Null Hypothesis:μ1=μ2
#
# ##### Alternative Hypthosis: μ1 not equal μ2
#
# 2976 Females μ1= 29.94
#
#  7.75
#
# 2759 Male Adults
# μ = 28.78
#
# G 6.25
#
# μ1-μ2 = 1.16

# %%
url = 'nhanes_2015_2016.csv'

da = pd.read_csv(url)
da.head()
# Out:
#     SEQN  ALQ101  ALQ110  ALQ130  SMQ020  RIAGENDR  RIDAGEYR  RIDRETH1  \
# 0  83732     1.0     NaN     1.0       1         1        62         3
# 1  83733     1.0     NaN     6.0       1         1        53         3
# 2  83734     1.0     NaN     NaN       1         1        78         3
# 3  83735     2.0     1.0     1.0       2         2        56         3
# 4  83736     2.0     1.0     1.0       2         2        42         4
#
#    DMDCITZN  DMDEDUC2  ...  BPXSY2  BPXDI2  BMXWT  BMXHT  BMXBMI  BMXLEG  \
# 0       1.0       5.0  ...   124.0    64.0   94.8  184.5    27.8    43.3
# 1       2.0       3.0  ...   140.0    88.0   90.4  171.4    30.8    38.0
# 2       1.0       3.0  ...   132.0    44.0   83.4  170.1    28.8    35.6
# 3       1.0       5.0  ...   134.0    68.0  109.8  160.9    42.4    38.5
# 4       1.0       4.0  ...   114.0    54.0   55.2  164.9    20.3    37.4
#
#    BMXARML  BMXARMC  BMXWAIST  HIQ210
# 0     43.6     35.9     101.1     2.0
# ...

# %%
females = da[da['RIAGENDR']== 2]
male = da[da['RIAGENDR']== 1]

# %%
male.head()
# Out:
#     SEQN  ALQ101  ALQ110  ALQ130  SMQ020  RIAGENDR  RIDAGEYR  RIDRETH1  \
# 0  83732     1.0     NaN     1.0       1         1        62         3
# 1  83733     1.0     NaN     6.0       1         1        53         3
# 2  83734     1.0     NaN     NaN       1         1        78         3
# 6  83741     1.0     NaN     8.0       1         1        22         4
# 8  83743     NaN     NaN     NaN       2         1        18         5
#
#    DMDCITZN  DMDEDUC2  ...  BPXSY2  BPXDI2  BMXWT  BMXHT  BMXBMI  BMXLEG  \
# 0       1.0       5.0  ...   124.0    64.0   94.8  184.5    27.8    43.3
# 1       2.0       3.0  ...   140.0    88.0   90.4  171.4    30.8    38.0
# 2       1.0       3.0  ...   132.0    44.0   83.4  170.1    28.8    35.6
# 6       1.0       4.0  ...   112.0    74.0   76.6  165.4    28.0    38.8
# 8       1.0       NaN  ...     NaN     NaN   72.4  166.1    26.2     NaN
#
#    BMXARML  BMXARMC  BMXWAIST  HIQ210
# 0     43.6     35.9     101.1     2.0
# ...

# %%
n1 = len(females)
nu2 = females['BMXBMI'].mean()
sd1 = females['BMXBMI'].std()

(n1, nu2, sd1)
# Out:
# (2976, 29.939945652173996, 7.75331880954568)

# %%
n2 = len(male)
nu2 = male['BMXBMI'].mean()
sd2 = male['BMXBMI'].std()

(n2, nu2, sd2)
# Out:
# (2759, 28.778072111846985, 6.252567616801485)

# %%
sn.stats.ztest(females['BMXBMI'].dropna(), male['BMXBMI'].dropna())
# Out:
# (6.1755933531383205, 6.591544431126401e-10)
