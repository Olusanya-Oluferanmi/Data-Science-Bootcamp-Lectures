# %% [markdown]
# # Simple linear regression

# %% [markdown]
# ## Import the relevant libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
import seaborn as sns
sns.set()

# %% [markdown]
# ## Load the data

# %%
data= pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Copy of Simple linear regression.csv')

# %%
data.head()
# Out:
#      SAT   GPA
# 0   1714  2.40
# 1   1664  2.52
# 2   1760  2.54
# 3   1685  2.74
# 4   1693  2.83
# ..   ...   ...
# 79  1936  3.71
# 80  1810  3.71
# 81  1987  3.73
# 82  1962  3.76
# 83  2050  3.81
#
# [84 rows x 2 columns]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# A statistical description of the data
data.describe()
# Out:
#                SAT        GPA
# count    84.000000  84.000000
# mean   1845.273810   3.330238
# std     104.530661   0.271617
# min    1634.000000   2.400000
# 25%    1772.000000   3.190000
# 50%    1846.000000   3.380000
# 75%    1934.000000   3.502500
# max    2050.000000   3.810000

# %% [markdown]
# ## Create the multiple linear regression

# %% [markdown]
# ### Declare the dependent and the independent variables

# %%
# define dependent and independent variable
x= data['SAT']
y = data['GPA']

# %%
x.shape
# Out:
# (84,)

# %%
y.shape
# Out:
# (84,)

# %%
x_matrix = x.values.reshape(84,1)

# %% [markdown]
# ## Regression itself

# %%
from sklearn.linear_model import LinearRegression

reg = LinearRegression()

# %%
reg.fit(x_matrix,y)
# Out:
# LinearRegression()

# %% [markdown]
# Standardization: the process of subtracting the mean and dividing by the standard deviation(a type of normalization)
# Normalization: has different meaning depending in the case; here - we subtract the mean but divide the L2-norm of the inputs
# copy_x: if true;it copies the input before fitting them. It is a safety net against normalization and other transformation
# n_jobs: is a parameter used when we want to parallelize routine

# %% [markdown]
# ### R-squared

# %%
reg.score(x_matrix,y)
# Out:
# 0.40600391479679754

# %% [markdown]
# ### Coefficients

# %%
reg.coef_
# Out:
# array([0.00165569])

# %% [markdown]
# ### Intercept

# %%
# A single regression always has a single intercept 
reg.intercept_
# Out:
# 0.2750402996602799

# %% [markdown]
# ### Making predictions

# %%
#returns the predictions of the linear regression model for some new input
reg.predict(1740)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-0e5fb3913d77> in <module>
#       1 #returns the predictions of the linear regression model for some new input
# ----> 2 reg.predict(1740)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_base.py in predict(self, X)
#     360             Returns predicted values.
#     361         """
# --> 362         return self._decision_function(X)
#     363
#     364     _preprocess_data = staticmethod(_preprocess_data)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_base.py in _decision_function(self, X)
#     343         check_is_fitted(self)
#     344
# --> 345         X = self._validate_data(X, accept_sparse=["csr", "csc", "coo"], reset=False)
#     346         return safe_sparse_dot(X, self.coef_.T, dense_output=True) + self.intercept_
#     347
#
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     564             raise ValueError("Validation should be done on X, y or both.")
#     565         elif not no_val_X and no_val_y:
# --> 566             X = check_array(X, **check_params)
#     567             out = X
#     568         elif no_val_X and not no_val_y:
#
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     763                     "Reshape your data either using array.reshape(-1, 1) if "
#     764                     "your data has a single feature or array.reshape(1, -1) "
# --> 765                     "if it contains a single sample.".format(array)
#     766                 )
#     767             # If input is 1D raise error
#
# ValueError: Expected 2D array, got scalar array instead:
# array=1740.
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.

# %%
new_data = pd.DataFrame(data=[1740,1760], columns =['SAT'])

# %%
reg.predict(new_data)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:444: UserWarning: X has feature names, but LinearRegression was fitted without feature names
#   f"X has feature names, but {self.__class__.__name__} was fitted without"
# array([3.15593751, 3.18905127])

# %%
new_data['Predicted_GPA'] = reg.predict(new_data)
new_data
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:444: UserWarning: X has feature names, but LinearRegression was fitted without feature names
#   f"X has feature names, but {self.__class__.__name__} was fitted without"
#     SAT  Predicted_GPA
# 0  1740       3.155938
# 1  1760       3.189051

# %% [markdown]
# ### Explore the data

# %%
# # Visualize the relationship in the two vaiables
# plt.scatter(x1,y)
# plt.xlabel('SAT',fontsize=20)
# plt.ylabel('GPA',fontsize=20)
# plt.show()

# %% [markdown]
# ### Regression itself

# %%
# # Ordinary least squares regession
# x = sm.add_constant(x1)
# results = sm.OLS(y,x).fit()
# results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    GPA   R-squared:                       0.406
# Model:                            OLS   Adj. R-squared:                  0.399
# Method:                 Least Squares   F-statistic:                     56.05
# Date:                Fri, 10 Jun 2022   Prob (F-statistic):           7.20e-11
# Time:                        13:36:53   Log-Likelihood:                 12.672
# No. Observations:                  84   AIC:                            -21.34
# Df Residuals:                      82   BIC:                            -16.48
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.2750      0.409      0.673      0.503      -0.538       1.088
# SAT            0.0017      0.000      7.487      0.000       0.001       0.002
# ==============================================================================
# Omnibus:                       12.839   Durbin-Watson:                   0.950
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):               16.155
# Skew:                          -0.722   Prob(JB):                     0.000310
# Kurtosis:                       4.590   Cond. No.                     3.29e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.29e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# ### Plot the regression line on the initial scatter

# %%
plt.scatter(x1,y)
yhat = 0.0017*x1 + 0.275 #yhat =B0(coefficient) +B1*X1 
fig = plt.plot(x1, yhat, lw=4, c='orange', label='regression line')
plt.xlabel('SAT', fontsize = 20)
plt.ylabel('GPA', fontsize = 20)
plt.show()

# %%
plt.scatter(x1,y)
yhat = 0.0017*x1 + 0 #yhat =B0(coefficient) +B1*X1 
fig = plt.plot(x1, yhat, lw=4, c='red', label='regression line')
plt.xlabel('SAT', fontsize = 20)
plt.ylabel('GPA', fontsize = 20)
plt.show()

# %%
plt.scatter(x1,y)
yhat = 0*x1 + 0.275 #yhat =B0(coefficient) +B1*X1 
fig = plt.plot(x1, yhat, lw=4, c='green', label='regression line')
plt.xlabel('SAT', fontsize = 20)
plt.ylabel('GPA', fontsize = 20)
plt.show()
