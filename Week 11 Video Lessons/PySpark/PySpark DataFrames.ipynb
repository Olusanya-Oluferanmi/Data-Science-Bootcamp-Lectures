# %% [markdown]
#  Week 11: Day 5 – PySpark With Python-PySpark DataFrames

# %% [markdown]
# - ## Objectives
#
#
# - Pyspark DataFrame
# - Reading The Dataset
# - Checking the DataTypes of the columns(Schema)
# - Selecting Columns And Indexing
# - Check Describe Option Similar To Pandas
# - Adding Columns
# - Dropping Columns
# - Renaming Columns

# %%
# import sparksession
from pyspark.sql import SparkSession

# %%
# start session
spark = SparkSession.builder.appName('Dataframe').getOrCreate()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14884/390963941.py in <module>
#       1 # start session
# ----> 2 spark = SparkSession.builder.appName('Dataframe').getOrCreate()
#
# ~\Anaconda3\envs\pyspark_env\lib\site-packages\pyspark\sql\session.py in getOrCreate(self)
#     226                             sparkConf.set(key, value)
#     227                         # This SparkContext may be an existing one.
# --> 228                         sc = SparkContext.getOrCreate(sparkConf)
#     229                     # Do not update `SparkConf` for existing `SparkContext`, as it's shared
#     230                     # by all sessions.
#
# ~\Anaconda3\envs\pyspark_env\lib\site-packages\pyspark\context.py in getOrCreate(cls, conf)
#     390         with SparkContext._lock:
#     391             if SparkContext._active_spark_context is None:
# ...

# %%
spark

# %%
# Read the dataset: method 1
df_pyspark=spark.read.option('header', 'true').csv('test1pyspark.csv', inferSchema=True).show()
# if you don't indicate inferSchema as true it will recognize all 
#the values as string 
# If you don't remove the .show() you'll get an error while 
#checking for the schema because it has being put into vaviable pyspark thus affecting the outcome

# %%
# Check the schema(datatype)
df_pyspark.printSchema()

# %%
# Read the dataset: method 2
df_pyspark=spark.read.csv('test1pyspark.csv', header=True, inferSchema=True)
df_pyspark.show()

# %%
# Find data type
type(df_pyspark)
# dataframe is a data structure where you can perform various operations
# types: pyspark, pandas

# %%
#Selecting Columns 
df_pyspark.head()
# it's output is usually in a list format

# %%
# returns it in a dataframe format
df_pyspark.show()

# %%
# How to pick up columns
df_pyspark.select('Name').show()

# %%
# returns datatype
type(df_pyspark.select('Name'))

# %%
# How to pick up multiple columns
df_pyspark.select(['Name', 'Experience']).show()

# %%
# returns datatype of all the columns
df_pyspark.dtypes
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14884/1067083382.py in <module>
#       1 # returns datatype of all the columns
# ----> 2 df_pyspark.dtypes
#
# NameError: name 'df_pyspark' is not defined

# %%
## Check Describe Option Similar To Pandas
df_pyspark.describe().show()
# it describes string columns too

# %%
#Adding Columns in dataframe
df_pyspark.withColumn('Experience After 2 years',df_pyspark['Experience']+2 )

# %%
df_pyspark.withColumn('Experience After 2 years',df_pyspark['Experience']+2 ).show()

# %%
df_pyspark=df_pyspark.withColumn('Experience After 2 years',df_pyspark['Experience']+2 )
df_pyspark.show()

# %%
# Drop the columns
df_pyspark=df_pyspark.drop('Experience After 2 years')

# %%
df_pyspark.show()

# %%
## Rename the columns
df_pyspark.withColumnRenamed('Name','New Name').show()
