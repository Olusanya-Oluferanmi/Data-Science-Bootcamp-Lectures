# %% [markdown]
# # Week 3: Day 2 - Matplotlib, Seaborn For Data Visualization

# %% [markdown]
# ### Basic ploting with matplotlib

# %% [markdown]
# ### Matplotlib
#
# Matplotlib is a Python library that helps in visualizing and analyzing the data and helps in better understanding of the data with the help of graphical, pictorial visualizations that can be simulated using the matplotlib library.

# %%
# Importing necessary packages for displaying images
from PIL import Image
import numpy as np
from IPython.display import display

# %%
im=Image.open('matplotlib.jpg')
display(im)
array=np.array
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=298x169 at 0x2867C47EDF0>

# %%
# importing the matplotlib library in order to use the pyplot library

import matplotlib.pyplot as plt

# %%
# lets do a basic plot example of a point x at 5 unit on the y axis and also 5 unit on the x axis.
# plt.show() displays the plot on our jupyter notebook.

plt.plot(5,5, 'x')

plt.show()

# %%
# plt.ylabel() labels the y axis
# plt.xlabel() labels the x axis
# plt.title() gives title to your graph

plt.plot(5,5,'o')

plt.ylabel("Y")
plt.xlabel("X")
plt.title(" Plotting Example")
plt.show()

# %% [markdown]
# ### Introduction to Data Visulization
#
# Data visualization is the pictorial or graphical representation of information or data, by using visual elements like charts, graphs, and maps. Data visualization tools provide an accessible way to see and understand trends, outliers, and patterns in ones data.

# %%
# importing Libraries to help with data visualization
# importing Libraries to help with reading and manipulating data

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# ## Basic Graph
#
# A basic graph consists of a vertical and a horizontal line that intersects at a point called origin. The horizontal line is the x axis, the vertical line is the y axis.

# %%
# we created an element and stored it in the variable x and y
# plt.figure() resize your graph
# plt.title()  gives title to your graph, plt.xlabel() label the x axis, plt.ylabel() labels the y axis.
# plt.xticks() sets the x-axis tick values, which are the locations along the x-axis where the tick marks appear.
# plt.legend() Place a legend on the Axes,Legends are a useful way to label data series plotted on a graph.
#plt.savefig() The point of plt.savefig() is it allows you to export the graph to a file.

x = [0,1,2,3,4,]
y = [0,2,4,6,8,]

plt.figure(figsize=(5,3), dpi=200)

#plt.plot(x,y, label='2x', color='red', linewidth=2, marker='.', linestyle= '--', markersize= 10, markeredgecolor='blue')
# use shorthand notation
#fmt = '[color][marker][line]'
plt.plot(x,y, 'g^--',  label='2x')

## line number 2
x2 = np.arange(0,4.5,0.5)
plt.plot(x2[:6], x2[:6]**2, 'r', label='X^2')
plt.plot(x2[5:], x2[5:]**2, 'r--')



plt.title('Our First Graph', fontdict={'fontname': 'Comic Sans MS', 'fontsize': 20})
plt.xlabel('X Axis')
plt.ylabel('Y Axis')

plt.xticks([0,1,2,3,4])
#plt.yticks([0,2,4,6,8,10])

plt.legend()

plt.savefig('mygraph.png', dpi=300)

plt.show()
# Out:
# findfont: Font family ['Comic Sans MS'] not found. Falling back to DejaVu Sans.

# %% [markdown]
# ### BAR CHART
#
# A bar chart or bar graph is a chart or graph that presents categorical data with rectangular bars with heights or lengths proportional to the values that they represent. The bars can be plotted vertically or horizontally.

# %%
labels =["A","B", "C"]
values =[1,4,2]

bars = plt.bar(labels,values)

patterns = ['/', 'o', '*']
for bar in bars:
    bar.set_hatch(patterns.pop(0))

# bars[0].set_hatch('/')
# bars[1].set_hatch('o')
# bars[2].set_hatch('*')




plt.figure(figsize=(6,4))

plt.savefig('mybarchart.png', dpi=300)
plt.show()

# %% [markdown]
# ### LINE GRAPH
#
# A line graph is a graphical display of information that changes continuously over time. Within a line graph, there are various data points connected together by a straight line that reveals a continuous change in the values represented by the data points.

# %%
# importing the necessary libaries

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
#Loading the dataset 
gas = pd.read_csv("C:\\Users\\Zachary_B\\Desktop\\dataset\\gas_prices.csv")
gas
# Out:
#     Year  Australia  Canada  France  Germany  Italy  Japan  Mexico  \
# 0   1990        NaN    1.87    3.63     2.65   4.59   3.16    1.00
# 1   1991       1.96    1.92    3.45     2.90   4.50   3.46    1.30
# 2   1992       1.89    1.73    3.56     3.27   4.53   3.58    1.50
# 3   1993       1.73    1.57    3.41     3.07   3.68   4.16    1.56
# 4   1994       1.84    1.45    3.59     3.52   3.70   4.36    1.48
# 5   1995       1.95    1.53    4.26     3.96   4.00   4.43    1.11
# 6   1996       2.12    1.61    4.41     3.94   4.39   3.64    1.25
# 7   1997       2.05    1.62    4.00     3.53   4.07   3.26    1.47
# 8   1998       1.63    1.38    3.87     3.34   3.84   2.82    1.49
# 9   1999       1.72    1.52    3.85     3.42   3.87   3.27    1.79
# 10  2000       1.94    1.86    3.80     3.45   3.77   3.65    2.01
# 11  2001       1.71    1.72    3.51     3.40   3.57   3.27    2.20
# 12  2002       1.76    1.69    3.62     3.67   3.74   3.15    2.24
# ...

# %%
plt.title('Gas Prices over time (in USD)', fontdict= {'fontweight' :'bold', 'fontsize': 18})


plt.plot(gas.Year, gas.USA, 'b.-',label= 'USA',)
plt.plot(gas.Year, gas.Canada, 'r.-', label= 'Canada')
plt.plot(gas.Year, gas['South Korea'], 'g.-', label= 'South Korea')
plt.plot(gas.Year, gas.Australia, 'y.-', label= 'Australia')

#countries_to_look_at =['Australia', 'USA', 'Canada', 'South Korea']
#for country in gas:
#    if country in countries_to_look_at :
#        plt.plot(gas.Year, gas[country], marker= '.' )



print(gas.Year [::3])
plt.xticks(gas.Year [::3].tolist()+[2011])

plt.xlabel('Year')
plt.ylabel('US Dollars')


plt.legend()

plt.savefig('Gas_price_figure.png', dpi=300)

plt.show()
# Out:
# 0     1990
# 3     1993
# 6     1996
# 9     1999
# 12    2002
# 15    2005
# 18    2008
# Name: Year, dtype: int64

# %% [markdown]
# ### Load Fifa Data

# %%
# Importing necessary libraries
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# The .head() method returns the first five values in your data set
fifa = pd.read_csv("C:\\Users\\Zachary_B\\Desktop\\dataset\\fifa_data.csv")
fifa.head(5)
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# ...

# %% [markdown]
# ### Histograms
#
# A histogram is a graphical representation that organizes a group of data points into user-specified ranges. Similar in appearance to a bar graph, the histogram condenses a data series into an easily interpreted visual by taking many data points and grouping them into logical ranges or bins.

# %%
# plt.hist() it computes and draws the histogram of your data
plt.hist(fifa.Overall)

plt.show()

# %%
# The bins parameter assings values to your histogram bars
bins = [40, 50, 60, 70, 80, 90, 100]

plt.hist(fifa.Overall, bins=bins)


plt.show()

# %%
bins = [40, 50, 60, 70, 80, 90, 100]

plt.hist(fifa.Overall, bins=bins)

plt.xticks(bins)

plt.ylabel('Number of Players')
plt.xlabel('Skill Level')
plt.title('Distribution of Player Skills in FIFA 2018')


plt.show()

# %%
bins = [80, 90, 100]

plt.hist(fifa.Overall, bins=bins)

plt.xticks(bins)

plt.ylabel('Number of Players')
plt.xlabel('Skill Level')
plt.title('Distribution of Player Skills in FIFA 2018')


plt.show()

# %%
# The color parameter sets the color of your histogram bars

bins = [40, 50, 60, 70, 80, 90, 100]

plt.hist( fifa.Overall, bins=bins, color='#83f442')

plt.xticks(bins)

plt.ylabel('Number of Players')
plt.xlabel('Skill Level')
plt.title('Distribution of Player Skills in FIFA 2018')

plt.hist()
plt.show()

# %%
bins = [40, 50, 60, 70, 80, 90, 100]

plt.hist(fifa.Overall, bins=bins, color='#abcdef')

plt.xticks(bins)

plt.ylabel('Number of Players')
plt.xlabel('Skill Level')
plt.title('Distribution of Player Skills in FIFA 2018')


plt.show()

# %% [markdown]
# ### Pie Charts
#
# A pie chart (or a circle chart) is a circular statistical graphic, which is divided into slices to illustrate numerical proportion.

# %%
# The .head() returns the first five values of your data set
fifa.head(5)
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# ...

# %%
# The .loc accesses a group of rows and columns in your dataset.
# The .count() returns the number of times a particular value appears in your dataset

left = fifa.loc[fifa['Preferred Foot'] == 'Left'].count()
 

left
# Out:
# Unnamed: 0        4211
# ID                4211
# Name              4211
# Age               4211
# Photo             4211
#                   ...
# GKHandling        4211
# GKKicking         4211
# GKPositioning     4211
# GKReflexes        4211
# Release Clause    3820
# Length: 89, dtype: int64

# %%
left = fifa.loc[fifa['Preferred Foot'] == 'Left'].count()[0]
left
# Out:
# 4211

# %%
left = fifa.loc[fifa['Preferred Foot'] == 'Left'].count()[0]
right = fifa.loc[fifa['Preferred Foot'] == 'Right'].count()[0]
right
# Out:
# 13948

# %%
# plt.pie() plots a pie chart of your dataset

left = fifa.loc[fifa['Preferred Foot'] == 'Left'].count()[0]
right = fifa.loc[fifa['Preferred Foot'] == 'Right'].count()[0]

plt.pie([left, right])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# labels parameter assings label to the graph

left = fifa.loc[fifa['Preferred Foot'] == 'Left'].count()[0]
right = fifa.loc[fifa['Preferred Foot'] == 'Right'].count()[0]

labels=['Left', 'Right']
colors = ['#abcdef', '#aabbcc']

plt.pie([left, right], labels=labels, colors=colors, autopct='%.2f %%')

plt.title('Foot Preference of FIFA Players')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
fifa.Weight
# Out:
# 0        159lbs
# 1        183lbs
# 2        150lbs
# 3        168lbs
# 4        154lbs
#           ...
# 18202    134lbs
# 18203    170lbs
# 18204    148lbs
# 18205    154lbs
# 18206    176lbs
# Name: Weight, Length: 18207, dtype: object

# %%
#The strip() method removes any spaces or specified characters at the start and end of a string.
fifa.Weight = [x.strip('lbs') if type (x) == str else x for x in fifa.Weight]
fifa.Weight
# Out:
# 0        159
# 1        183
# 2        150
# 3        168
# 4        154
#         ...
# 18202    134
# 18203    170
# 18204    148
# 18205    154
# 18206    176
# Name: Weight, Length: 18207, dtype: object

# %%
fifa.Weight = [x.strip('lbs') if type (x) == str else x for x in fifa.Weight]
fifa.Weight[0]
# Out:
# '159'

# %%
fifa.Weight = [int(x.strip('lbs')) if type (x) == str else x for x in fifa.Weight]
fifa.Weight[0]
# Out:
# 159.0

# %%
fifa.Weight = [int(x.strip('lbs')) if type (x) == str else x for x in fifa.Weight]

light = fifa.loc[fifa.Weight < 125].count()[0]
light_medium = fifa.loc[(fifa.Weight >= 125) & (fifa.Weight < 150)].count()[0]
medium = fifa[(fifa.Weight >= 150) & (fifa.Weight < 175)].count()[0]
medium_heavy = fifa[(fifa.Weight >= 175) & (fifa.Weight < 200)].count()[0]
heavy = fifa[(fifa.Weight >= 200)].count()[0]

Weights = [light, light_medium, medium, medium_heavy, heavy]  
                    
plt.pie(Weights) 
plt.show()

# %%
fifa.Weight = [int(x.strip('lbs')) if type (x) == str else x for x in fifa.Weight]

light = fifa.loc[fifa.Weight < 125].count()[0]
light_medium = fifa.loc[(fifa.Weight >= 125) & (fifa.Weight < 150)].count()[0]
medium = fifa[(fifa.Weight >= 150) & (fifa.Weight < 175)].count()[0]
medium_heavy = fifa[(fifa.Weight >= 175) & (fifa.Weight < 200)].count()[0]
heavy = fifa[(fifa.Weight >= 200)].count()[0]

Weights = [light, light_medium, medium, medium_heavy, heavy]  
labels = ['Under 125', '125-150', '150-175', '175-200', 'Over 200']


plt.pie(Weights, labels = labels) 
plt.show()

# %%
fifa.Weight = [int(x.strip('lbs')) if type (x) == str else x for x in fifa.Weight]

plt.style.use('ggplot')

light = fifa.loc[fifa.Weight < 125].count()[0]
light_medium = fifa.loc[(fifa.Weight >= 125) & (fifa.Weight < 150)].count()[0]
medium = fifa[(fifa.Weight >= 150) & (fifa.Weight < 175)].count()[0]
medium_heavy = fifa[(fifa.Weight >= 175) & (fifa.Weight < 200)].count()[0]
heavy = fifa[(fifa.Weight >= 200)].count()[0]

Weights = [light, light_medium, medium, medium_heavy, heavy]  
labels = ['Under 125', '125-150', '150-175', '175-200', 'Over 200']


plt.pie(Weights, labels = labels, autopct= '%.2f %%', pctdistance =0.8) 
plt.show()

# %%
# We use the style.use() method to style the plots, the "ggplot" style adjusts the style to emulate ggplot (a popular plotting package for R). 
fifa.Weight = [int(x.strip('lbs')) if type (x) == str else x for x in fifa.Weight]

plt.style.use('ggplot')

light = fifa.loc[fifa.Weight < 125].count()[0]
light_medium = fifa.loc[(fifa.Weight >= 125) & (fifa.Weight < 150)].count()[0]
medium = fifa[(fifa.Weight >= 150) & (fifa.Weight < 175)].count()[0]
medium_heavy = fifa[(fifa.Weight >= 175) & (fifa.Weight < 200)].count()[0]
heavy = fifa[(fifa.Weight >= 200)].count()[0]

Weights = [light, light_medium, medium, medium_heavy, heavy]  
labels = ['Under 125', '125-150', '150-175', '175-200', 'Over 200']
explode = [.4,.2,0,0,.4]

plt.title('Weights Distribution of FIFA Players (in lbs)')

plt.pie(Weights, labels = labels, autopct= '%.2f %%', pctdistance =0.8, explode=explode) 
plt.show()

# %%
fifa
# Out:
#        Unnamed: 0      ID                Name  Age  \
# 0               0  158023            L. Messi   31
# 1               1   20801   Cristiano Ronaldo   33
# 2               2  190871           Neymar Jr   26
# 3               3  193080              De Gea   27
# 4               4  192985        K. De Bruyne   27
# ...           ...     ...                 ...  ...
# 18202       18202  238813        J. Lundstram   19
# 18203       18203  243165  N. Christoffersson   19
# 18204       18204  241638           B. Worman   16
# 18205       18205  246268      D. Walker-Rice   17
# 18206       18206  246269           G. Nugent   16
#
#                                                 Photo Nationality  \
# 0      https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1       https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2      https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3      https://cdn.sofifa.org/players/4/19/193080.png       Spain
# ...

# %%
# A Box Plot is created to display the summary of the set of data values having properties like minimum,  first quartile, median, third quartile and
# maximum.
plt.style.use('default')

barcelona = fifa.loc[fifa.Club == 'FC Barcelona']['Overall']
madrid = fifa.loc[fifa.Club == 'Real Madrid']['Overall']


labels = ['FC Barcelona', 'Real Madrid']

plt.boxplot([barcelona, madrid], labels = labels)

plt.show()

# %%
plt.style.use('default')

plt.figure(figsize=(5,8))

barcelona = fifa.loc[fifa.Club == 'FC Barcelona']['Overall']
madrid = fifa.loc[fifa.Club == 'Real Madrid']['Overall']
revs = fifa.loc[fifa.Club == 'New England Revolution']['Overall']

labels = ['FC Barcelona', 'Real Madrid', 'NE Revolution']

plt.boxplot([barcelona, madrid, revs], labels = labels)

plt.title('Professional Soccer Team Comparison')
plt.ylabel('FIFA Overall Rating')

plt.show()

# %%
plt.style.use('default')

plt.figure(figsize=(5,8))

barcelona = fifa.loc[fifa.Club == 'FC Barcelona']['Overall']
madrid = fifa.loc[fifa.Club == 'Real Madrid']['Overall']
revs = fifa.loc[fifa.Club == 'New England Revolution']['Overall']

labels = ['FC Barcelona', 'Real Madrid', 'NE Revolution']

boxes = plt.boxplot([barcelona, madrid, revs], labels = labels, patch_artist=True, medianprops={'linewidth':2})
for box in boxes['boxes']:
    # set edge color
    box.set(color='#4286f4', linewidth=2)
    
    # change fill color
    box.set(facecolor='#e0e0e0')

plt.title('Professional Soccer Team Comparison')
plt.ylabel('FIFA Overall Rating')

plt.show()

# %% [markdown]
# # Seaborn
#
# Seaborn is a data visualization library in python based on the matplotlib library. It provides a high-level interface for drawing attractive and informative statistical graphics.

# %%
from PIL import Image
from IPython.display import display

# %%
im=Image.open('Seaborn.jpg')
display(im)
array=np.array
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=318x159 at 0x2867C47EC10>

# %% [markdown]
# ## Setup

# %%
# importing necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

#matplotlib inline
#reload_ext autoreload
#autoreload  2

# %%
#Loading the dataset
cs_df = pd.read_csv('C:\\Users\\Zachary_B\\Desktop\\dataset\\ComputerSales.csv')
cs_df.head()
# Out:
#    Sale ID      Contact Sex  Age State Product ID Product Type  Sale Price  \
# 0        1  Paul Thomas   M   43    OH  M01-F0024      Desktop      479.99
# 1        2  Margo Simms   F   37    WV  GT13-0024      Desktop     1249.99
# 2        3    Sam Stine   M   26    PA      I3670      Desktop      649.99
# 3        4   Moe Eggert   M   35    PA      I3593       Laptop      399.99
# 4        5  Jessica Elk   F   55    PA     15M-ED       Laptop      699.99
#
#    Profit     Lead     Month  Year
# 0  143.39  Website   January  2018
# 1  230.89  Flyer 4   January  2018
# 2  118.64  Website  February  2018
# 3   72.09  Website     March  2018
# 4   98.09  Flyer 4     March  2018

# %%
#The print() function prints the specified argument to the screen
# The sns.get_dataset_names() function is for one to check what preloaded datasets are available for plotting in the Seaborn library.
print(sns.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'exercise', 'flights', 'fmri', 'gammas', 'geyser', 'iris', 'mpg', 'penguins', 'planets', 'taxis', 'tips', 'titanic']

# %%
crash_df = sns.load_dataset('car_crashes')
crash_df
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0    18.8     7.332    5.640          18.048       15.040       784.55
# 1    18.1     7.421    4.525          16.290       17.014      1053.48
# 2    18.6     6.510    5.208          15.624       17.856       899.47
# 3    22.4     4.032    5.824          21.056       21.280       827.34
# 4    12.0     4.200    3.360          10.920       10.680       878.41
# 5    13.6     5.032    3.808          10.744       12.920       835.50
# 6    10.8     4.968    3.888           9.396        8.856      1068.73
# 7    16.2     6.156    4.860          14.094       16.038      1137.87
# 8     5.9     2.006    1.593           5.900        5.900      1273.89
# 9    17.9     3.759    5.191          16.468       16.826      1160.13
# 10   15.6     2.964    3.900          14.820       14.508       913.15
# 11   17.5     9.450    7.175          14.350       15.225       861.18
# ...

# %% [markdown]
# ### Distribution Plot
#
# Distribution plot is used to visualise the distribution of data over a continuous interval or time period

# %%
# sns.distplot() plots a distribution graph of your dataset
sns.distplot(crash_df['not_distracted'], kde =False, bins=25)
# Out:
# C:\Users\Zachary_B\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='not_distracted'>

# %% [markdown]
# ### Joint Plot
#
# Joint plot provides a concise way to understand both the relationship between two variables as well as the individual distribution of each variable. The joint plot actually consist of three seperat plots.

# %%
#sns.jointplot() plots a jointplot of your dataset
sns.jointplot(x='speeding', y='alcohol', data=crash_df, kind='reg')

# %%
sns.jointplot(x='speeding', y='alcohol', data=crash_df, kind='kde')

# %%
sns.jointplot(x='speeding', y='alcohol', data=crash_df, kind='hex')

# %% [markdown]
# KDE Plot
#
# A kernel density estimate (KDE) plot is a method for visualizing the distribution of observations in a dataset, analagous to a histogram. KDE represents the data using a continuous probability density curve in one or more dimensions.

# %%
sns.kdeplot(crash_df['alcohol'], label='-')
# Out:
# <AxesSubplot:xlabel='alcohol', ylabel='Density'>

# %% [markdown]
# ### Pair Plot
#
# A pairplot plots a pairwise relationships in a dataset. The pairplot function creates a grid of Axes such that each variable in data will by shared in the y-axis across a single row and in the x-axis across a single column.

# %%
sns.pairplot(crash_df)

# %%
sns.pairplot(crash_df)

tips_df= sns.load_dataset('tips')
tips_df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips_df= sns.load_dataset('tips')

sns.pairplot(tips_df, hue='sex', palette='Blues')

# %% [markdown]
# ### Rug Plot
#
# A rug plot is a plot of data values for a single quantitative variable, it is displayed as marks along an axis. It is also used to visualise the distribution of the data.

# %%
sns.rugplot(tips_df['tip'])
# Out:
# <AxesSubplot:xlabel='tip'>

# %% [markdown]
# ### Styling
#
# Styling is a way you design your graph or plot, here you set the background color to suit your desire.

# %%
sns.set_style('white')

sns.jointplot(x='speeding', y='alcohol', data=crash_df, kind='reg')

# %%
sns.set_style('darkgrid')

plt.figure(figsize=(8,4))

sns.jointplot(x='speeding', y='alcohol', data=crash_df, kind='reg')

# %%
sns.set_style('whitegrid')

plt.figure(figsize=(8,4))

sns.jointplot(x='speeding', y='alcohol', data=crash_df, kind='reg')

# %%
sns.set_style('dark')

plt.figure(figsize=(8,4))

sns.jointplot(x='speeding', y='alcohol', data=crash_df, kind='reg')

# %%
# .set() is a pyplot interface that allows one to use set to set an object properties respectively.
sns.set_style('ticks')

plt.figure(figsize=(8,4))

sns.set_context('paper', font_scale =1.4)

sns.jointplot(x='speeding', y='alcohol', data=crash_df, kind='reg')

# %%
sns.set_style('ticks')

plt.figure(figsize=(8,4))

sns.set_context('talk', font_scale =1.4)

sns.jointplot(x='speeding', y='alcohol', data=crash_df, kind='reg')

# %%
sns.set_style('ticks')

plt.figure(figsize=(8,4))

sns.set_context('poster', font_scale =1.4)

sns.jointplot(x='speeding', y='alcohol', data=crash_df, kind='reg')
# Out:
# C:\Users\Zachary_B\anaconda3\lib\site-packages\seaborn\axisgrid.py:1668: UserWarning: Tight layout not applied. tight_layout cannot make axes width small enough to accommodate all axes decorations
#   f.tight_layout()

# %%
# sns.set_context() Set the parameters that control the scaling of plot elements. This affects things like the size of the labels, lines, and other elements of the plot, but not the overall style.
# The base context is “notebook”, and the other contexts are “paper”, “talk”, and “poster”, which are version of the notebook parameters scaled by different values. .
sns.set_style('ticks')

plt.figure(figsize=(8,4))

sns.set_context('paper', font_scale =1.5)

sns.jointplot(x='speeding', y='alcohol', data=crash_df, kind='reg')
sns.despine(left = False)

# %%
# sns.despine() is used to remove the top and right spines from plot(s).
# Axis spines are the lines confining the plot area.
sns.set_style('ticks')

plt.figure(figsize=(8,4))

sns.set_context('paper', font_scale =1.5)

sns.jointplot(x='speeding', y='alcohol', data=crash_df, kind='reg')
sns.despine(left = True, bottom= True)

# %% [markdown]
# ### Categorical Plotting
#
# Plots are basically used for visualizing the relationship between variables. Those variables can be either be completely numerical or a categorical like a group, class or division.

# %%
# A barplot is basically used to aggregate the categorical data according to some methods and by default it's mean.
sns.barplot(x='sex', y='total_bill', data=tips_df)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='total_bill'>

# %%
sns.barplot(x='sex', y='total_bill', data=tips_df, estimator =np.median)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='total_bill'>

# %%
sns.barplot(x='sex', y='total_bill', data=tips_df, estimator =np.std)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='total_bill'>

# %%
sns.barplot(x='sex', y='total_bill', data=tips_df, estimator =np.var)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='total_bill'>

# %%
sns.barplot(x='sex', y='total_bill', data=tips_df, estimator =np.cov)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='total_bill'>

# %% [markdown]
# ### Count Plot
# A countplot basically counts the categories and returns a count of their occurrences

# %%
sns.countplot(x = 'sex', data= tips_df)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %% [markdown]
# ### Box Plot
# A boxplot is sometimes known as the box and whisker plot. It shows the distribution of the quantitative data that represents the comparisons between variables.

# %%
sns.boxplot(x = 'day', y = 'total_bill', data= tips_df, hue='sex')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %% [markdown]
# ### Violin Plot
# A violin plot plays a similar role as a box and whisker plot. It shows the distribution of quantitative data across several levels of one (or more) categorical variables such that those distributions can be compared.

# %%
sns.violinplot(x = 'day', y = 'total_bill', data= tips_df, hue='sex')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x = 'day', y = 'total_bill', data= tips_df, hue='sex', split=True)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %% [markdown]
# ### Strip Plot
# It basically creates a scatter plot based on the category.

# %%
plt.figure(figsize=(8,5))

sns.stripplot(x = 'day', y = 'total_bill', data= tips_df, jitter=True)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
plt.figure(figsize=(8,5))

sns.stripplot(x = 'day', y = 'total_bill', data= tips_df, jitter=True, hue='sex')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
plt.figure(figsize=(8,5))

sns.stripplot(x = 'day', y = 'total_bill', data= tips_df, jitter=True, hue='sex', dodge=True)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %% [markdown]
# ### Swamp Plot

# %%
sns.violinplot(x = 'day', y = 'total_bill', data= tips_df)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x = 'day', y = 'total_bill', data= tips_df)
sns.swarmplot(x = 'day', y = 'total_bill', data= tips_df, color='white')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.swarmplot(x = 'day', y = 'total_bill', data= tips_df)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
plt.figure(figsize=(8,5))
sns.set_style('dark')
sns.set_context('talk')
sns.stripplot(x = 'day', y = 'total_bill', data= tips_df, hue= 'sex', palette='magma')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
plt.figure(figsize=(8,6))
sns.set_style('white')
sns.set_context('talk')
sns.stripplot(x = 'day', y = 'total_bill', data= tips_df, hue= 'sex', palette='afmhot')
plt.legend(loc=0)

# %% [markdown]
# ## Matrix Plots

# %% [markdown]
# ### Heatmaps
# A heat map is a data visualization technique that shows magnitude of a phenomenon as color in two dimensions.

# %%
plt.figure(figsize=(8,6))
sns.set_context('paper', font_scale=1.4)

crash_df
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0    18.8     7.332    5.640          18.048       15.040       784.55
# 1    18.1     7.421    4.525          16.290       17.014      1053.48
# 2    18.6     6.510    5.208          15.624       17.856       899.47
# 3    22.4     4.032    5.824          21.056       21.280       827.34
# 4    12.0     4.200    3.360          10.920       10.680       878.41
# 5    13.6     5.032    3.808          10.744       12.920       835.50
# 6    10.8     4.968    3.888           9.396        8.856      1068.73
# 7    16.2     6.156    4.860          14.094       16.038      1137.87
# 8     5.9     2.006    1.593           5.900        5.900      1273.89
# 9    17.9     3.759    5.191          16.468       16.826      1160.13
# 10   15.6     2.964    3.900          14.820       14.508       913.15
# 11   17.5     9.450    7.175          14.350       15.225       861.18
# ...

# %%
plt.figure(figsize=(8,6))
sns.set_context('paper', font_scale=1.4)

crash_mx = crash_df.corr()
crash_mx
# Out:
#                    total  speeding   alcohol  not_distracted  no_previous  \
# total           1.000000  0.611548  0.852613        0.827560     0.956179
# speeding        0.611548  1.000000  0.669719        0.588010     0.571976
# alcohol         0.852613  0.669719  1.000000        0.732816     0.783520
# not_distracted  0.827560  0.588010  0.732816        1.000000     0.747307
# no_previous     0.956179  0.571976  0.783520        0.747307     1.000000
# ins_premium    -0.199702 -0.077675 -0.170612       -0.174856    -0.156895
# ins_losses     -0.036011 -0.065928 -0.112547       -0.075970    -0.006359
#
#                 ins_premium  ins_losses
# total             -0.199702   -0.036011
# speeding          -0.077675   -0.065928
# alcohol           -0.170612   -0.112547
# not_distracted    -0.174856   -0.075970
# no_previous       -0.156895   -0.006359
# ins_premium        1.000000    0.623116
# ins_losses         0.623116    1.000000

# %%
# sns.heatmap() plots a heatmap of a dataset
plt.figure(figsize=(8,6))
sns.set_context('paper', font_scale=1.4)

crash_mx = crash_df.corr()

sns.heatmap(crash_mx, annot=True, cmap='Blues')
# Out:
# <AxesSubplot:>

# %%
flights = sns.load_dataset('flights')
flights
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
flights = sns.load_dataset('flights')
flights = flights.pivot_table(index='month', columns='year', values = 'passengers')
flights
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# ...

# %%
flights = sns.load_dataset('flights')
flights = flights.pivot_table(index='month', columns='year', values = 'passengers')
sns.heatmap(flights, cmap='Blues', linecolor='white', linewidth=1)
# Out:
# <AxesSubplot:xlabel='year', ylabel='month'>

# %% [markdown]
# ### Cluster Map
# The cluster corresponds with the number of markers contained within it. Zoom in closer on your map to see the individual markers and interact with them. Cluster maps are a great tool for determining how many data points are located in a specific region.

# %%
iris = sns.load_dataset('iris')
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
#species = iris.pop('species')
#sns.clustermap(iris)

# %%
sns.clustermap(flights, cmap='Blues', standard_scale=1)

# %% [markdown]
# ### PairGrid
# PairGrid allows us to draw a grid of subplots using the same plot type to visualize data.

# %%
iris = sns.load_dataset('iris')
#iris_g = sns.PairGrid(iris, hue='species')
#iris_g.map_diag(plt.hist)
#iris_g.map_offdiag(plt.scatter)
#iris_g.map_upper(plt.scatter)
#iris_g.map_lower(sns.kdeplot)
iris_g = sns.PairGrid(iris, hue='species',
                     x_vars =['sepal_length', 'sepal_width'],
                     y_vars =['petal_length', 'petal_width'])
iris_g.map(plt.scatter)
iris_g.add_legend()

# %% [markdown]
# ### Facet Grid
# FacetGrid class helps in visualizing distribution of one variable as well as the relationship between multiple variables separately within subsets of your dataset using multiple panels.

# %%
tips_fg =sns.FacetGrid(tips_df, col ="time", row='smoker')

# %%
tips_fg =sns.FacetGrid(tips_df, col ="time", row='smoker')
tips_fg.map(plt.hist, 'total_bill', bins=8)

# %%
tips_fg =sns.FacetGrid(tips_df, col ="time", row='smoker')
tips_fg.map(plt.scatter, 'total_bill', 'tip')

# %%
tips_fg =sns.FacetGrid(tips_df, col ="time", hue='smoker', height=4, aspect=1.3)
tips_fg.map(plt.scatter, 'total_bill', 'tip')

# %%
tips_fg =sns.FacetGrid(tips_df, col ="time", hue='smoker', height=4, aspect=1.3, col_order=['Dinner', 'Lunch'], palette='Set1')
tips_fg.map(plt.scatter, 'total_bill', 'tip', edgecolor='w')

# %%
#tips_fg =sns.FacetGrid(tips_df, col ="time", hue='smoker', height=4, aspect=1.3, col_order=['Dinner', 'Lunch'], palette='Set1')
#tips_fg.map(plt.scatter, 'total_bill', 'tip', edgecolor='w')

kws= dict(s=50, linewidth = .5, edgecolor = 'w')
tips_fig = sns.FacetGrid (tips_df, col='sex', hue = 'smoker', height =4, aspect= 1.3, hue_order =['Yes', 'No'], hue_kws =dict(marker =['^', 'v']))
tips_fig.map(plt.scatter, 'total_bill', 'tip', **kws)

# %%
#tips_fg =sns.FacetGrid(tips_df, col ="time", hue='smoker', height=4, aspect=1.3, col_order=['Dinner', 'Lunch'], palette='Set1')
#tips_fg.map(plt.scatter, 'total_bill', 'tip', edgecolor='w')

#tips_fig = sns.FacetGrid (tips_df, col='sex', hue = 'smoker', height =4, aspect= 1.3, hue_order =['Yes', 'No'], hue_kws =dict(marker =['^', 'v']))
#tips_fig.map(plt.scatter, 'total_bill', 'tip', **kws)

att_df = sns.load_dataset('attention')
att_fg = sns.FacetGrid(att_df, col= 'subject', col_wrap=5, height=1.5)

att_fg.map(plt.plot, 'solutions', 'score', marker='.')

# %% [markdown]
# ### Regression Plot
# The regression plots in seaborn are primarily intended to add a visual guide that helps to emphasize patterns in a dataset during exploratory data analyses.

# %%
tips_df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# loading the libraries to help read and visualize the data
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# sns.lmplot is a function in seaborn that plot data and regression model fits across a FacetGrid.
plt.figure(figsize=(8,5))
sns.set_context('paper', font_scale=1.4)
sns.lmplot(x='total_bill', y='tip', hue='sex', data= tips_df, markers= ['o', '^'], scatter_kws={'s': 100, 'linewidth': 0.5, 'edgecolor':'w'})

# %%
sns.set_context('paper', font_scale=1.4)
sns.lmplot(x='total_bill', y='tip', col='sex', row= 'time', data= tips_df)

# %%
sns.set_context('paper', font_scale=1.4)
sns.lmplot(x='total_bill', y='tip', col='sex', row= 'time', data= tips_df, height=8, aspect=0.6)

# %% [markdown]
# # Required Reading
